# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Leads.csv')
df.sample(5)
# Out:
#                                Prospect ID  Lead Number  \
# 2831  a6c07ece-8a57-4246-87fa-ee92adff6e0b       632524
# 7635  22b1f1dc-97ad-4477-b123-579e9194a128       591219
# 2335  9306f838-b4f0-4689-8151-9b069dfe1b6d       637183
# 8684  15c1191e-09a1-49b3-b3e5-d9207e7502fc       583534
# 3106  a6a680c4-b8c4-40bd-98bb-9c186e334f8e       630083
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 2831  Landing Page Submission  Direct Traffic           No          No
# 7635  Landing Page Submission  Direct Traffic          Yes          No
# 2335  Landing Page Submission  Direct Traffic           No          No
# 8684                      API          Google           No          No
# 3106                      API      Olark Chat           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 2831          0          4.0                          365
# 7635          0          1.0                          345
# ...

# %%
df.shape
# Out:
# (9240, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
((df.isnull().sum()/len(df))*100).sort_values(ascending=False)
# Out:
# Lead Quality                                     51.590909
# Asymmetrique Activity Index                      45.649351
# Asymmetrique Profile Score                       45.649351
# Asymmetrique Activity Score                      45.649351
# Asymmetrique Profile Index                       45.649351
# Tags                                             36.287879
# Lead Profile                                     29.318182
# What matters most to you in choosing a course    29.318182
# What is your current occupation                  29.112554
# Country                                          26.634199
# How did you hear about X Education               23.885281
# Specialization                                   15.562771
# City                                             15.367965
# Page Views Per Visit                              1.482684
# TotalVisits                                       1.482684
# Last Activity                                     1.114719
# ...

# %%
df=df.drop(columns=['Prospect ID','Lead Number','Lead Source','Asymmetrique Profile Score','Lead Quality',
               'Asymmetrique Activity Index','Asymmetrique Profile Score','Asymmetrique Activity Score',
               'Asymmetrique Profile Index','Tags','What is your current occupation','City'])

# %%
df.shape
# Out:
# (9240, 26)

# %%
df = df.applymap(lambda x: 1 if x == 'Yes' else 0 if x == 'No' else x)
# Out:
# C:\Users\sai\AppData\Local\Temp\ipykernel_15096\3876630994.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: 1 if x == 'Yes' else 0 if x == 'No' else x)

# %%
df
# Out:
#                   Lead Origin  Do Not Email  Do Not Call  Converted  \
# 0                         API             0            0          0
# 1                         API             0            0          0
# 2     Landing Page Submission             0            0          1
# 3     Landing Page Submission             0            0          0
# 4     Landing Page Submission             0            0          1
# ...                       ...           ...          ...        ...
# 9235  Landing Page Submission             1            0          1
# 9236  Landing Page Submission             0            0          0
# 9237  Landing Page Submission             1            0          0
# 9238  Landing Page Submission             0            0          1
# 9239  Landing Page Submission             0            0          1
#
#       TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0             0.0                            0                  0.00
# ...

# %%
((df.isnull().sum()/len(df))*100).sort_values(ascending=False)
# Out:
# Lead Profile                                     29.318182
# What matters most to you in choosing a course    29.318182
# Country                                          26.634199
# How did you hear about X Education               23.885281
# Specialization                                   15.562771
# TotalVisits                                       1.482684
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Lead Origin                                       0.000000
# Digital Advertisement                             0.000000
# A free copy of Mastering The Interview            0.000000
# I agree to pay the amount through cheque          0.000000
# Get updates on DM Content                         0.000000
# Update me on Supply Chain Content                 0.000000
# Receive More Updates About Our Courses            0.000000
# Through Recommendations                           0.000000
# ...

# %%
df_object = df.select_dtypes(include=['object'])
df_object
# Out:
#                   Lead Origin            Last Activity       Country  \
# 0                         API  Page Visited on Website           NaN
# 1                         API             Email Opened         India
# 2     Landing Page Submission             Email Opened         India
# 3     Landing Page Submission              Unreachable         India
# 4     Landing Page Submission        Converted to Lead         India
# ...                       ...                      ...           ...
# 9235  Landing Page Submission        Email Marked Spam  Saudi Arabia
# 9236  Landing Page Submission                 SMS Sent         India
# 9237  Landing Page Submission                 SMS Sent         India
# 9238  Landing Page Submission                 SMS Sent         India
# 9239  Landing Page Submission                 SMS Sent    Bangladesh
#
#                  Specialization How did you hear about X Education  \
# 0                        Select                             Select
# ...

# %%
df_object.shape
# Out:
# (9240, 8)

# %%
df['Lead Profile'] = df['Lead Profile'].replace('Select', 'NaN')
df['Specialization'] = df['Specialization'].replace('Select', 'NaN')
df['How did you hear about X Education'] = df['How did you hear about X Education'].replace('Select', 'NaN')

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='most_frequent')
new_df=si.fit_transform(df_object)
